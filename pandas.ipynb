# %% [markdown]
# <a href="https://colab.research.google.com/github/aysutnyva/Machine_Learning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Out:
# --2025-01-30 14:56:29--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv’
#
# car-sales.csv       100%[===================>]     369  --.-KB/s    in 0s
#
# 2025-01-30 14:56:29 (12.2 MB/s) - ‘car-sales.csv’ saved [369/369]

# %%
df = pd.read_csv('/content/car-sales.csv')
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
df.tail(10)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df[-5:]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
df.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
df.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
df.Doors
# Out:
# 0    4
# 1    4
# 2    3
# 3    5
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Doors, dtype: int64

# %%
df['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
df[['Make', 'Odometer (KM)', 'Price']].head(4)
# Out:
#      Make  Odometer (KM)       Price
# 0  Toyota         150043   $4,000.00
# 1   Honda          87899   $5,000.00
# 2  Toyota          32549   $7,000.00
# 3     BMW          11179  $22,000.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
df['Odometer (KM)'].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
dict1 = {'Namiq':[2,4,5,7,3],
         'Yusif':[4,6,7,3,5],
         'Aysel':[7,8,5,2,5]
         }

# %%
students = pd.DataFrame(dict1)
students
# Out:
#    Namiq  Yusif  Aysel
# 0      2      4      7
# 1      4      6      8
# 2      5      7      5
# 3      7      3      2
# 4      3      5      5

# %%
pd.Series(dict1)
# Out:
# Namiq    [2, 4, 5, 7, 3]
# Yusif    [4, 6, 7, 3, 5]
# Aysel    [7, 8, 5, 2, 5]
# dtype: object

# %%
pd.Series(dict1).iloc[0]
# Out:
# [2, 4, 5, 7, 3]

# %%
pd.Series(dict1).loc['Namiq']
# Out:
# [2, 4, 5, 7, 3]

# %%
students.Namiq.mean()
# Out:
# 4.2

# %%
students['Yusif'].max()
# Out:
# 7

# %%
students['Aysel'].count()
# Out:
# 5

# %%
students.Namiq.sum()
# Out:
# 21

# %%
students.std()
# Out:
# Namiq    1.923538
# Yusif    1.581139
# Aysel    2.302173
# dtype: float64

# %%
dict2 = {'Namiq':[2,None,5,7,3],
         'Yusif':[4,6,None,3,None],
         'Aysel':[7,None,5,2,5]
         }

# %%
missing_students = pd.DataFrame(dict2)
missing_students
# Out:
#    Namiq  Yusif  Aysel
# 0    2.0    4.0    7.0
# 1    NaN    6.0    NaN
# 2    5.0    NaN    5.0
# 3    7.0    3.0    2.0
# 4    3.0    NaN    5.0

# %%
missing_students.isna()
# Out:
#    Namiq  Yusif  Aysel
# 0  False  False  False
# 1   True  False   True
# 2  False   True  False
# 3  False  False  False
# 4  False   True  False

# %%
missing_students.isna().sum()
# Out:
# Namiq    1
# Yusif    2
# Aysel    1
# dtype: int64

# %%
missing_students.isnull()
# Out:
#    Namiq  Yusif  Aysel
# 0  False  False  False
# 1   True  False   True
# 2  False   True  False
# 3  False  False  False
# 4  False   True  False

# %%
missing_students.notnull() #notna
# Out:
#    Namiq  Yusif  Aysel
# 0   True   True   True
# 1  False   True  False
# 2   True  False   True
# 3   True   True   True
# 4   True  False   True

# %%
missing_students.notnull().sum()
# Out:
# Namiq    4
# Yusif    3
# Aysel    4
# dtype: int64

# %%
missing_students.rename(columns = {'Yusif':'Velish'}) #inplace=True
# Out:
#    Namiq  Velish  Aysel
# 0    2.0     4.0    7.0
# 1    NaN     6.0    NaN
# 2    5.0     NaN    5.0
# 3    7.0     3.0    2.0
# 4    3.0     NaN    5.0

# %%
missing_students.dropna(subset='Yusif')
# Out:
#    Namiq  Yusif  Aysel
# 0    2.0    4.0    7.0
# 1    NaN    6.0    NaN
# 3    7.0    3.0    2.0

# %%
missing_students.drop_duplicates(subset = 'Yusif')
# Out:
#    Namiq  Yusif  Aysel
# 0    2.0    4.0    7.0
# 1    NaN    6.0    NaN
# 2    5.0    NaN    5.0
# 3    7.0    3.0    2.0

# %%
missing_students['Aysel'].mean()
# Out:
# 4.75

# %%
missing_students.fillna(missing_students['Aysel'].mean())
# Out:
#    Namiq  Yusif  Aysel
# 0   2.00   4.00   7.00
# 1   4.75   6.00   4.75
# 2   5.00   4.75   5.00
# 3   7.00   3.00   2.00
# 4   3.00   4.75   5.00

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df[df['Odometer (KM)'] > 50_000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
df.groupby(by=['Make'])['Odometer (KM)']

# %%
df.drop('Colour', axis=1, #inplace = True)
# Out:
#      Make  Odometer (KM)  Doors       Price
# 0  Toyota         150043      4   $4,000.00
# 1   Honda          87899      4   $5,000.00
# 2  Toyota          32549      3   $7,000.00
# 3     BMW          11179      5  $22,000.00
# 4  Nissan         213095      4   $3,500.00
# 5  Toyota          99213      4   $4,500.00
# 6   Honda          45698      4   $7,500.00
# 7   Honda          54738      4   $7,000.00
# 8  Toyota          60000      4   $6,250.00
# 9  Nissan          31600      4   $9,700.00

# %%
df['Odometer per Doors'] = df['Odometer (KM)'] / df.Doors

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer per Doors
# 0  Toyota  White         150043      4   $4,000.00        37510.750000
# 1   Honda    Red          87899      4   $5,000.00        21974.750000
# 2  Toyota   Blue          32549      3   $7,000.00        10849.666667
# 3     BMW  Black          11179      5  $22,000.00         2235.800000
# 4  Nissan  White         213095      4   $3,500.00        53273.750000
# 5  Toyota  Green          99213      4   $4,500.00        24803.250000
# 6   Honda   Blue          45698      4   $7,500.00        11424.500000
# 7   Honda   Blue          54738      4   $7,000.00        13684.500000
# 8  Toyota  White          60000      4   $6,250.00        15000.000000
# 9  Nissan  White          31600      4   $9,700.00         7900.000000

# %%
df['Price'] = df['Price'].str.replace('$', '').str.replace(',', '')   #dollari atir

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Odometer per Doors
# 0  Toyota  White         150043      4   4,000.00        37510.750000
# 1   Honda    Red          87899      4   5,000.00        21974.750000
# 2  Toyota   Blue          32549      3   7,000.00        10849.666667
# 3     BMW  Black          11179      5  22,000.00         2235.800000
# 4  Nissan  White         213095      4   3,500.00        53273.750000
# 5  Toyota  Green          99213      4   4,500.00        24803.250000
# 6   Honda   Blue          45698      4   7,500.00        11424.500000
# 7   Honda   Blue          54738      4   7,000.00        13684.500000
# 8  Toyota  White          60000      4   6,250.00        15000.000000
# 9  Nissan  White          31600      4   9,700.00         7900.000000

# %%
df['Price'] = pd.to_numeric(df['Price'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                10 non-null     object
#  1   Colour              10 non-null     object
#  2   Odometer (KM)       10 non-null     int64
#  3   Doors               10 non-null     int64
#  4   Price               10 non-null     float64
#  5   Odometer per Doors  10 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 612.0+ bytes

# %%
# np where
